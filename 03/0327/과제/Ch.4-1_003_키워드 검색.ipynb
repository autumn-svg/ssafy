# %% [markdown]
# <font color='red'><b>**WARNING**</b></font> <br/>
# 어떠한 사유로도 임의로 복사, 촬영, 녹음, 복제, 보관, 전송하거나 허가 받지 않은 저장매체를 이용한 보관, 제3자에게 누설, 공개 또는 사용하는 등의 무단 사용 및 불법 배포 시 법적 조치를 받을 수 있습니다. <br/>
#
# <div style="text-align: right; color: #7f8c8d; font-size: 0.9em; margin-top: 20px;">
# 📝 Author: 박사홍 (Sahong Pak)</br>
# 📧 Contact: sahong.pak@gmail.com</br>
# 📌 Version: v2.0</br>
# 📅 Last Updated: 2026-03-12</br>
# </div>

# %% [markdown]
# # 학습 내용
# >이번 장에서는 <strong>키워드 검색(Keyword Search)</strong>에 대해 학습합니다.
# >키워드 기반으로 문서를 검색하고, 동의어 문제 등 한계를 직접 학습해봅시다.

# %% [markdown]
# # 키워드 검색 (Keyword Search)
# > 문서의 텍스트에서 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">정확히 일치하는 키워드</mark>를 찾아 관련 문서를 반환합니다.

# %% [markdown]
# 키워드 검색은 문서에서 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">입력한 단어가 그대로 포함된 위치</mark>를 찾는 방식입니다. 대표적인 알고리즘으로는 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">TF-IDF(Term Frequency-Inverse Document Frequency)</mark>가 있는데, 단어가 특정 문서에서 얼마나 자주 등장하는지(TF)와 전체 문서에서 얼마나 희귀한지(IDF)를 곱하여 중요도를 산출합니다. <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">BM25</mark>는 TF-IDF를 발전시킨 방식으로, 문서 길이를 보정하여 더 정교한 관련도 점수를 계산하며 현재도 많은 검색 엔진의 기반 알고리즘으로 쓰입니다.</br>
#
# 그러나 이 방식에는 명확한 한계가 있습니다. <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">동의어/유의어 처리 불가</mark>(예: "매출"과 "수익"은 같은 개념이지만 단어가 다르면 매칭되지 않음), <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">의미적 관계 파악 불가</mark>("회사 실적"처럼 직접 단어가 없어도 의미상 관련 있는 문서를 찾지 못함), <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">철자 변형 취약</mark>(띄어쓰기, 복수형, 활용형 차이에도 검색 결과가 달라짐) 등의 문제가 있습니다. 이번 실습에서는 이러한 원리와 한계를 직접 확인해봅니다.

# %%
# TODO 1: 키워드 검색 함수를 정의하여 문서의 텍스트에 키워드가 포함된 문서를 리스트로 반환하고, "매출" 키워드로 검색 결과를 출력해봅시다.

def keyword_search(documents, keyword):
    """키워드가 포함된 문서를 검색"""
    results = []
    for doc in documents:
        if keyword in doc.page_content:
            results.append(doc)
    return results

# 사용 예시
results = keyword_search(documents, "매출")
print(f"검색 결과: {len(results)}건")
for doc in results[:2]:
    print(f"  [p.{doc.metadata.get('page', '?')}] {doc.page_content[:80]}...")

# %% [markdown]
# ## Document 객체 접근 패턴
# > 검색 결과는 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">Document 리스트</mark>이며, 각 Document의 `page_content`로 텍스트에 접근합니다.

# %%
# TODO 2: 검색 결과 리스트를 순회하며 각 문서의 텍스트 내용과 메타데이터를 변수에 저장하고, 페이지 번호와 내용 앞 50자를 출력해봅시다.

for doc in results:
    content = doc.page_content   # 텍스트 내용
    meta = doc.metadata          # 메타데이터
    print(f"[p.{meta.get('page', '?')}] {content[:50]}...")

# %% [markdown]
# # 키워드 검색의 한계 (Limitations)
# > 키워드 검색은 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">동의어, 유의어</mark>를 처리하지 못합니다.

# %%
# TODO 3: 검색어 리스트에 "매출", "수익", "revenue", "실적"을 저장하고, 각 키워드로 검색을 실행하여 검색 건수를 비교해봅시다.

queries = ["매출", "수익", "revenue", "실적"]
for query in queries:
    result = keyword_search(documents, query)
    print(f"'{query}' → {len(result)}건 {'✓' if result else '✗'}")

# %% [markdown]
# ## 키워드 검색 vs 의미 검색

# %% [markdown]
# <table style="width:100%">
#   <thead>
#     <tr>
#       <th style="text-align:center">비교 항목</th>
#       <th>키워드 검색</th>
#       <th>의미 기반 검색</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td style="text-align:center">매칭 방식</td><td><mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">문자열 정확 일치</mark></td><td>벡터 유사도</td></tr>
#     <tr><td style="text-align:center">동의어</td><td>처리 불가</td><td><mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">자동 처리</mark></td></tr>
#     <tr><td style="text-align:center">속도</td><td>빠름</td><td>상대적으로 느림</td></tr>
#     <tr><td style="text-align:center">정확도</td><td>키워드 의존</td><td>문맥 이해</td></tr>
#   </tbody>
# </table>

# %% [markdown]
# 💡키워드 검색의 근본적 한계
# > 같은 의미라도 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">다른 단어</mark>를 사용하면 검색되지 않습니다.
# > "매출" vs "수익" vs "revenue"는 모두 같은 개념이지만 키워드 검색으로는 연결할 수 없습니다.

# %% [markdown]
# 💡해결 방향
# > 텍스트를 <mark style="background-color:#FFF9C4; padding:2px 6px; border-radius:4px;">벡터(임베딩)</mark>로 변환하면 의미적 유사성을 계산할 수 있습니다.
# > 이것이 의미 기반 검색(Semantic Search)의 핵심 아이디어입니다.
